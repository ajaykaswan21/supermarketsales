# %% [markdown]
# # Assignment

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('supermarket_sales - supermarket_sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # Question
#
# As always, do your EDA, find me insights. I want a good section going over this, what you find me, i don't know. At the end, your mention some actionable items for a business, that it can do to perform better.
#
# ![](https://media.giphy.com/media/ukwPlCmJ5RmlqvQCpA/giphy.gif)
#
#
# ### Modeling
# - Fit a Simple Linear Regression Model, that tries to predict the ```Rating``` column with the help of the ```Total``` Column. We only have to use these 2 columns, nothing more.
#     - What was the training accuracy.
#     - What was the testing accuracy.
#
#
# ---
#
#
# - Make a python function, that takes ```Total``` as an input, and predicts what the ```Rating``` will be using your newly trained model to assist you !!
# - Just to be clear, your function will take 1 float value as an input and return back a float value as an output.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
axList = df.hist(figsize = (17, 17))
plt.savefig("Hist.png")

# %% [markdown]
# # Montly transaction in comparsion with Gender

# %%
plt.title("Montly transaction")
sns.countplot(x=df["Gender"]);

# %%
df.Gender.value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %% [markdown]
# # Total montly transaction with each product line

# %%
plt.title("total monthly Transaction")
sns.countplot(x=df["Product line"])
plt.xticks(rotation=50);

# %% [markdown]
# # Transaction % in each product line

# %%
explode=(0.15,0.05,0.05,0.05,0.05,0.05)

df["Product line"].value_counts().plot.pie(autopct="%1.5f%%",startangle=90,explode=explode)

plt.title("Transaction per month");

# %% [markdown]
# # Highest tranaction in the cities and Branches

# %%
plt.title("Total Monthly Tranaction")
sns.countplot(x=df["City"],hue = df["Branch"]);

# %%
plt.figure()
plt.title("total monthly Transaction")
sns.countplot(x=df["Branch"],hue=df["Product line"])
plt.xticks(rotation=40)
plt.legend(loc="best"); 
plt.show()

# %% [markdown]
# # Customer types

# %%
plt.title("Count plot of customers types")
sns.countplot(x=df["Customer type" ]);

# %%
df["Customer type"].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %% [markdown]
# # Purchases in city with Gender wise

# %%
plt.title("Frequency of purchases genderwise")
sns.countplot(x=df.City,hue=df.Gender);

# %% [markdown]
# # Source of Payment

# %%
sns.countplot(x=df.Payment);

# %%
sns.barplot(x=df.Payment,y=df["Total"]);

# %% [markdown]
# # Product Line with gross income

# %%
sns.barplot(x=df["Product line"],y=df["gross income"]);
plt.xticks(rotation=50);

# %% [markdown]
# # Product line with Rating

# %%
sns.barplot(y=df["Product line"],x=df["Rating"]);

# %%
sns.barplot(x=df["Total"],y=df["Product line"]);

# %%
sns.histplot(df["Quantity"]);

# %% [markdown]
# # Correlation between price and quantity

# %%
sns.heatmap(df.corr(),annot=True);
# Out:
# /var/folders/4t/flkqq_hn3474p78hfyx8dlz00000gn/T/ipykernel_8944/1422343944.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# # Here we go

# %%
X = df['Total']
X.head()
# Out:
# 0    548.9715
# 1     80.2200
# 2    340.5255
# 3    489.0480
# 4    634.3785
# Name: Total, dtype: float64

# %%
y = df['Rating']
y.head()
# Out:
# 0    9.1
# 1    9.6
# 2    7.4
# 3    8.4
# 4    5.3
# Name: Rating, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.75,random_state=100)
X_train.shape
X_train.values.reshape(-1,1)
# Out:
# array([[ 603.876 ],
#        [ 786.618 ],
#        [  57.876 ],
#        [  33.495 ],
#        [ 338.2155],
#        [ 130.032 ],
#        [ 688.716 ],
#        [ 196.14  ],
#        [ 667.38  ],
#        [ 321.111 ],
#        [ 703.752 ],
#        [  78.0045],
#        [ 282.492 ],
#        [ 203.553 ],
#        [  33.936 ],
#        [ 384.72  ],
#        [ 408.408 ],
#        [  91.8225],
#        [ 926.9505],
#        [ 181.44  ],
#        [ 431.256 ],
#        [ 860.685 ],
#        [ 462.21  ],
#        [ 137.004 ],
#        [ 517.965 ],
#        [  36.5505],
#        [ 131.922 ],
#        [ 253.512 ],
#        [ 152.712 ],
#        [  93.744 ],
#        [ 362.712 ],
#        [ 121.569 ],
#        [ 365.904 ],
#        [ 293.139 ],
#        [ 110.0925],
#        [ 629.8425],
#        [ 588.42  ],
#        [ 194.985 ],
#        [ 246.4875],
#        [ 224.4375],
#        [ 503.7375],
#        [ 874.125 ],
#        [  16.107 ],
#        [ 253.26  ],
#        [  30.219 ],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[1050.0]])
# Out:
# array([6.66180375])

# %%
y_pred_test = lr.predict(X_test)

# %%
y_pred_test
# Out:
# array([6.86955398, 6.98368946, 7.04537076, 7.0800936 , 7.00261141,
#        6.89492214, 7.00088505, 7.03035226, 6.71396879, 6.97766846,
#        6.95983505, 6.83142519, 6.95885706, 6.99337155, 6.79047299,
#        6.92224628, 7.00274748, 6.83955099, 7.00250936, 7.08187524,
#        6.89379533, 7.03435351, 6.83209277, 7.07394503, 7.04037026,
#        7.02014717, 7.0458555 , 7.03872044, 6.942716  , 6.92584358,
#        6.99710916, 6.89852794, 7.07626243, 7.02668693, 7.0567622 ,
#        6.8371613 , 7.0290171 , 7.07178495, 6.91735634, 6.9925679 ,
#        6.91682483, 6.89080183, 6.90223579, 6.78974162, 7.02503711,
#        6.87128034, 7.05229322, 7.04041279, 7.04554935, 6.86260601,
#        6.95207918, 6.81084066, 6.9220677 , 6.88309273, 7.06190727,
#        6.75126841, 6.74875541, 7.05269292, 7.0706794 , 6.76769862,
#        6.94483356, 7.03912864, 6.92545239, 6.97395635, 6.85376584,
#        7.08107159, 6.96368748, 6.98011768, 6.83027286, 7.07550556,
# ...

# %%
y_test
# Out:
# 249    4.2
# 353    4.8
# 537    6.9
# 424    5.0
# 564    9.0
#       ...
# 662    5.9
# 454    4.7
# 474    6.6
# 917    6.8
# 849    4.2
# Name: Rating, Length: 250, dtype: float64

# %% [markdown]
# # What was the testing accuracy.

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_test,y_pred_test)
# Out:
# 3.0075908719689988

# %%
mse = mean_squared_error(y_test,y_pred_test)

# %%
r2_score(y_test,y_pred_test)
# Out:
# -0.008547960151905842

# %%
x_range = [i for i in range(len(y_test))]

# %%
plt.xlabel('Total')
plt.ylabel('Ratings')
plt.title('Prediction')

plt.plot(x_range,y_test)
plt.plot(x_range,y_pred_test)


plt.legend(["Real", "Predicted"])

# %% [markdown]
# # What was the train accuracy.

# %%
y_pred_train = lr.predict(X_train)

# %%
y_train
# Out:
# 786    5.5
# 152    7.4
# 925    9.0
# 501    9.1
# 920    5.1
#       ...
# 855    4.2
# 871    9.6
# 835    5.8
# 792    4.9
# 520    7.7
# Name: Rating, Length: 750, dtype: float64

# %%
mean_squared_error(y_train,y_pred_train)
# Out:
# 2.9285116449354973

# %%
mse = mean_squared_error(y_train,y_pred_train)

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.0034309138103360004

# %%
x_range = [i for i in range(len(y_train))]

# %%
plt.xlabel('Total')
plt.ylabel('Ratings')
plt.title('Prediction')

plt.plot(x_range,y_train)
plt.plot(x_range,y_pred_train)

 
plt.legend(["Real", "Predicted"])
plt.show()

# %% [markdown]
# # Make a python function

# %%
def my_function(x):
    temp=[]
    temp.append(lr.predict([[x]]))
    return temp
my_function(1050.0)
# Out:
# [array([6.66180375])]
